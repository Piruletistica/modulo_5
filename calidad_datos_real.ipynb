# %%
# !pip install pandas

# %%
# !pip install pymongo

# %%
import pandas as pd

# %%
import pymongo

# %%
from pymongo import MongoClient

# %%
#cliente = MongoClient('localhost', 27017)

# %%
# Almacenar la conexión a MongoDB en una variable
cliente = MongoClient("mongodb://localhost:27017/")

# Seleccionar la base de datos y la colección
db = cliente["bootcamp_tech"]
coleccion = db["alumnos_bootcamp"]

# Obtener todos los registros dentro de la tabla y guardarlos como una lista de diccionarios
registros = list(coleccion.find())

# Convertir todos los registros a un DataFrame para su tratamiento
df = pd.DataFrame(registros)

# %%
df
# Out:
#                          _id alumno_id            nombre  \
# 0   688acbe7ad7a66240ce67464      A001     Carla Ramírez
# 1   688acbe7ad7a66240ce67465      A002      M4rcos Silva
# 2   688acbe7ad7a66240ce67466      A003               Ana
# 3   688acbe7ad7a66240ce67467      A004    Pedro Martinez
# 4   688acbe7ad7a66240ce67468      A005    María González
# ..                       ...       ...               ...
# 95  688acc19ad7a66240ce674c4      A046     Bruno Sánchez
# 96  688acc19ad7a66240ce674c5      A047  Agustina Paredes
# 97  688acc19ad7a66240ce674c6      A048    Leonardo Muñoz
# 98  688acc19ad7a66240ce674c7      A049   Esperanza López
# 99  688acc19ad7a66240ce674c8      A050    Nicolás Vargas
#
#                           email    telefono       programa fecha_ingreso  \
# 0       carla.ramirez@gmail.com   987654321     Full Stack    2024-01-15
# 1      marcos.silva@hotmail.com   912345678   Data Science    2024-01-15
# ...

# %%
df.isna().sum()
# Out:
# _id                    0
# alumno_id              0
# nombre                 4
# email                 22
# telefono               4
# programa               2
# fecha_ingreso         10
# edad                  16
# experiencia_previa    96
# estado                94
# ultima_conexion       94
# rut                   96
# dtype: int64

# %%
df[df["nombre"].isna()|(df["nombre"].str.strip()=="")]
df
# Out:
#                          _id alumno_id            nombre  \
# 0   688acbe7ad7a66240ce67464      A001     Carla Ramírez
# 1   688acbe7ad7a66240ce67465      A002      M4rcos Silva
# 2   688acbe7ad7a66240ce67466      A003               Ana
# 3   688acbe7ad7a66240ce67467      A004    Pedro Martinez
# 4   688acbe7ad7a66240ce67468      A005    María González
# ..                       ...       ...               ...
# 95  688acc19ad7a66240ce674c4      A046     Bruno Sánchez
# 96  688acc19ad7a66240ce674c5      A047  Agustina Paredes
# 97  688acc19ad7a66240ce674c6      A048    Leonardo Muñoz
# 98  688acc19ad7a66240ce674c7      A049   Esperanza López
# 99  688acc19ad7a66240ce674c8      A050    Nicolás Vargas
#
#                           email    telefono       programa fecha_ingreso  \
# 0       carla.ramirez@gmail.com   987654321     Full Stack    2024-01-15
# 1      marcos.silva@hotmail.com   912345678   Data Science    2024-01-15
# ...

# %%
df.describe()
# Out:
#             edad
# count  84.000000
# mean   26.285714
# std     2.813785
# min    22.000000
# 25%    24.000000
# 50%    26.000000
# 75%    28.000000
# max    33.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   _id                 100 non-null    object
#  1   alumno_id           100 non-null    object
#  2   nombre              96 non-null     object
#  3   email               78 non-null     object
#  4   telefono            96 non-null     object
#  5   programa            98 non-null     object
#  6   fecha_ingreso       90 non-null     object
#  7   edad                84 non-null     float64
#  8   experiencia_previa  4 non-null      object
#  9   estado              6 non-null      object
#  10  ultima_conexion     6 non-null      object
#  11  rut                 4 non-null      object
# dtypes: float64(1), object(11)
# memory usage: 9.5+ KB

# %%
#mostrar los datos unicos de la columna nombre
columnas_criticas = df[df["nombre"].astype(str).str.contains(r"\d", regex =True)]
columnas_criticas
# Out:
#                          _id alumno_id        nombre  \
# 1   688acbe7ad7a66240ce67465      A002  M4rcos Silva
# 51  688acc19ad7a66240ce67498      A002  M4rcos Silva
#
#                        email   telefono      programa fecha_ingreso  edad  \
# 1   marcos.silva@hotmail.com  912345678  Data Science    2024-01-15  28.0
# 51  marcos.silva@hotmail.com  912345678  Data Science    2024-01-15  28.0
#
#    experiencia_previa estado ultima_conexion  rut
# 1                 NaN    NaN             NaN  NaN
# 51                NaN    NaN             NaN  NaN
